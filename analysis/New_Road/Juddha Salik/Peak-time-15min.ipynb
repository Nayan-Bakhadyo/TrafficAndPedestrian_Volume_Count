# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Excel file
file_path = 'time_added_logs/Toward_OldBaneshwor_1630_1830/Toward_OldBaneshwor_1630_1830line2.xlsx'
df = pd.read_excel(file_path)

objects = ['person']
df2 = df[df['ObjectType'].isin(objects)]
df = df2

# Convert the 'Time' column to datetime format
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')

# Filter the DataFrame to include only 'North' directions
North_directions = ['North', 'NorthEast', 'NorthWest']
df_north = df[df['Direction'].isin(North_directions)].copy()

# Filter the DataFrame to include only 'South' directions
South_directions = ['SouthEast', 'South', 'SouthWest', 'East', 'West']
df_south = df[df['Direction'].isin(South_directions)].copy()

# Define the time range
start_time = pd.to_datetime('16:30:00', format='%H:%M:%S')
end_time = pd.to_datetime('18:30:00', format='%H:%M:%S')

# Define the interval duration (in minutes)
interval_duration = 1
# Create an empty DatetimeIndex
intervals = pd.DatetimeIndex([])
# Generate intervals within the time range
for i in range(0,interval_duration):
    start_time = start_time + pd.Timedelta(minutes=1)
    interval = pd.date_range(start=start_time, end=end_time, freq=f'{interval_duration}T')
    intervals = intervals.append(interval)
intervals = intervals.sort_values()
print(intervals)

# Calculate interval counts for North direction
north_interval_counts = []
for interval_start in intervals:
    interval_end = interval_start + pd.Timedelta(minutes=interval_duration)
    count = ((df_north['Time'] >= interval_start) & (df_north['Time'] < interval_end)).sum()
    north_interval_counts.append(count)

# Calculate interval counts for South direction
south_interval_counts = []
for interval_start in intervals:
    interval_end = interval_start + pd.Timedelta(minutes=interval_duration)
    count = ((df_south['Time'] >= interval_start) & (df_south['Time'] < interval_end)).sum()
    south_interval_counts.append(count)

df_north_interval_count= pd.DataFrame(columns=['Start_time','End_time', 'Count'])
df_south_interval_count= pd.DataFrame(columns=['Start_time','End_time', 'Count'])

# Print the interval counts
for interval_start, count_north, count_south in zip(intervals, north_interval_counts, south_interval_counts):
    interval_end = interval_start + pd.Timedelta(minutes=interval_duration)
    print(f"Interval {interval_start.strftime('%H:%M')} - {interval_end.strftime('%H:%M')} (North): {count_north}, (South): {count_south}")
    df_north_interval_count.loc[len(df_north_interval_count)] = {'Start_time': interval_start.strftime('%H:%M'),'End_time':interval_end.strftime('%H:%M'), 'Count': count_north}
    df_south_interval_count.loc[len(df_south_interval_count)] = {'Start_time': interval_start.strftime('%H:%M'),'End_time':interval_end.strftime('%H:%M'), 'Count': count_south}

# Plotting (optional)
plt.plot(intervals, north_interval_counts, label='North Direction')
plt.plot(intervals, south_interval_counts, label='South Direction')
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Interval Counts Analysis')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# DatetimeIndex(['1900-01-01 16:31:00', '1900-01-01 16:32:00',
#                '1900-01-01 16:33:00', '1900-01-01 16:34:00',
#                '1900-01-01 16:35:00', '1900-01-01 16:36:00',
#                '1900-01-01 16:37:00', '1900-01-01 16:38:00',
#                '1900-01-01 16:39:00', '1900-01-01 16:40:00',
#                ...
#                '1900-01-01 18:21:00', '1900-01-01 18:22:00',
#                '1900-01-01 18:23:00', '1900-01-01 18:24:00',
#                '1900-01-01 18:25:00', '1900-01-01 18:26:00',
#                '1900-01-01 18:27:00', '1900-01-01 18:28:00',
#                '1900-01-01 18:29:00', '1900-01-01 18:30:00'],
#               dtype='datetime64[ns]', length=120, freq=None)
# Interval 16:31 - 16:32 (North): 14, (South): 12
# Interval 16:32 - 16:33 (North): 4, (South): 8
# Interval 16:33 - 16:34 (North): 11, (South): 15
# Interval 16:34 - 16:35 (North): 14, (South): 13
# Interval 16:35 - 16:36 (North): 16, (South): 24
# Interval 16:36 - 16:37 (North): 11, (South): 9
# Interval 16:37 - 16:38 (North): 6, (South): 9
# Interval 16:38 - 16:39 (North): 8, (South): 8
# Interval 16:39 - 16:40 (North): 10, (South): 10
# Interval 16:40 - 16:41 (North): 2, (South): 9
# Interval 16:41 - 16:42 (North): 8, (South): 9
# Interval 16:42 - 16:43 (North): 2, (South): 13
# Interval 16:43 - 16:44 (North): 12, (South): 10
# Interval 16:44 - 16:45 (North): 7, (South): 5
# Interval 16:45 - 16:46 (North): 12, (South): 9
# Interval 16:46 - 16:47 (North): 10, (South): 9
# Interval 16:47 - 16:48 (North): 10, (South): 10
# Interval 16:48 - 16:49 (North): 8, (South): 5
# Interval 16:49 - 16:50 (North): 6, (South): 7
# Interval 16:50 - 16:51 (North): 8, (South): 8
# Interval 16:51 - 16:52 (North): 12, (South): 12
# Interval 16:52 - 16:53 (North): 9, (South): 8
# Interval 16:53 - 16:54 (North): 7, (South): 13
# Interval 16:54 - 16:55 (North): 6, (South): 14
# Interval 16:55 - 16:56 (North): 11, (South): 12
# Interval 16:56 - 16:57 (North): 9, (South): 3
# Interval 16:57 - 16:58 (North): 12, (South): 18
# Interval 16:58 - 16:59 (North): 10, (South): 20
# Interval 16:59 - 17:00 (North): 8, (South): 9
# Interval 17:00 - 17:01 (North): 17, (South): 18
# Interval 17:01 - 17:02 (North): 3, (South): 8
# Interval 17:02 - 17:03 (North): 6, (South): 10
# Interval 17:03 - 17:04 (North): 6, (South): 9
# Interval 17:04 - 17:05 (North): 5, (South): 17
# Interval 17:05 - 17:06 (North): 8, (South): 5
# Interval 17:06 - 17:07 (North): 8, (South): 6
# Interval 17:07 - 17:08 (North): 10, (South): 8
# Interval 17:08 - 17:09 (North): 7, (South): 17
# Interval 17:09 - 17:10 (North): 8, (South): 13
# Interval 17:10 - 17:11 (North): 8, (South): 11
# Interval 17:11 - 17:12 (North): 6, (South): 25
# Interval 17:12 - 17:13 (North): 18, (South): 15
# Interval 17:13 - 17:14 (North): 9, (South): 22
# Interval 17:14 - 17:15 (North): 17, (South): 9
# Interval 17:15 - 17:16 (North): 9, (South): 9
# Interval 17:16 - 17:17 (North): 4, (South): 6
# Interval 17:17 - 17:18 (North): 8, (South): 9
# Interval 17:18 - 17:19 (North): 9, (South): 8
# Interval 17:19 - 17:20 (North): 5, (South): 7
# Interval 17:20 - 17:21 (North): 2, (South): 0
# Interval 17:21 - 17:22 (North): 0, (South): 1
# Interval 17:22 - 17:23 (North): 1, (South): 1
# Interval 17:23 - 17:24 (North): 1, (South): 4
# Interval 17:24 - 17:25 (North): 4, (South): 7
# Interval 17:25 - 17:26 (North): 16, (South): 11
# Interval 17:26 - 17:27 (North): 32, (South): 38
# Interval 17:27 - 17:28 (North): 16, (South): 12
# Interval 17:28 - 17:29 (North): 5, (South): 9
# Interval 17:29 - 17:30 (North): 6, (South): 12
# Interval 17:30 - 17:31 (North): 3, (South): 12
# Interval 17:31 - 17:32 (North): 3, (South): 3
# Interval 17:32 - 17:33 (North): 5, (South): 6
# Interval 17:33 - 17:34 (North): 2, (South): 7
# Interval 17:34 - 17:35 (North): 0, (South): 7
# Interval 17:35 - 17:36 (North): 7, (South): 4
# Interval 17:36 - 17:37 (North): 5, (South): 6
# Interval 17:37 - 17:38 (North): 5, (South): 6
# Interval 17:38 - 17:39 (North): 1, (South): 8
# Interval 17:39 - 17:40 (North): 6, (South): 11
# Interval 17:40 - 17:41 (North): 5, (South): 6
# Interval 17:41 - 17:42 (North): 1, (South): 7
# Interval 17:42 - 17:43 (North): 4, (South): 4
# Interval 17:43 - 17:44 (North): 10, (South): 4
# Interval 17:44 - 17:45 (North): 10, (South): 8
# Interval 17:45 - 17:46 (North): 5, (South): 10
# Interval 17:46 - 17:47 (North): 6, (South): 3
# Interval 17:47 - 17:48 (North): 1, (South): 0
# Interval 17:48 - 17:49 (North): 4, (South): 3
# Interval 17:49 - 17:50 (North): 8, (South): 6
# Interval 17:50 - 17:51 (North): 9, (South): 5
# Interval 17:51 - 17:52 (North): 1, (South): 8
# Interval 17:52 - 17:53 (North): 2, (South): 6
# Interval 17:53 - 17:54 (North): 4, (South): 12
# Interval 17:54 - 17:55 (North): 9, (South): 4
# Interval 17:55 - 17:56 (North): 2, (South): 2
# Interval 17:56 - 17:57 (North): 4, (South): 7
# Interval 17:57 - 17:58 (North): 5, (South): 7
# Interval 17:58 - 17:59 (North): 1, (South): 0
# Interval 17:59 - 18:00 (North): 5, (South): 10
# Interval 18:00 - 18:01 (North): 2, (South): 6
# Interval 18:01 - 18:02 (North): 5, (South): 8
# Interval 18:02 - 18:03 (North): 0, (South): 2
# Interval 18:03 - 18:04 (North): 2, (South): 2
# Interval 18:04 - 18:05 (North): 3, (South): 9
# Interval 18:05 - 18:06 (North): 2, (South): 12
# Interval 18:06 - 18:07 (North): 3, (South): 4
# Interval 18:07 - 18:08 (North): 7, (South): 4
# Interval 18:08 - 18:09 (North): 5, (South): 4
# Interval 18:09 - 18:10 (North): 9, (South): 1
# Interval 18:10 - 18:11 (North): 13, (South): 7
# Interval 18:11 - 18:12 (North): 5, (South): 6
# Interval 18:12 - 18:13 (North): 6, (South): 6
# Interval 18:13 - 18:14 (North): 4, (South): 6
# Interval 18:14 - 18:15 (North): 4, (South): 1
# Interval 18:15 - 18:16 (North): 12, (South): 5
# Interval 18:16 - 18:17 (North): 3, (South): 8
# Interval 18:17 - 18:18 (North): 2, (South): 2
# Interval 18:18 - 18:19 (North): 1, (South): 6
# Interval 18:19 - 18:20 (North): 5, (South): 9
# Interval 18:20 - 18:21 (North): 4, (South): 2
# Interval 18:21 - 18:22 (North): 0, (South): 4
# Interval 18:22 - 18:23 (North): 3, (South): 1
# Interval 18:23 - 18:24 (North): 4, (South): 2
# Interval 18:24 - 18:25 (North): 5, (South): 5
# Interval 18:25 - 18:26 (North): 6, (South): 4
# Interval 18:26 - 18:27 (North): 1, (South): 1
# Interval 18:27 - 18:28 (North): 5, (South): 3
# Interval 18:28 - 18:29 (North): 6, (South): 3
# Interval 18:29 - 18:30 (North): 5, (South): 6
# Interval 18:30 - 18:31 (North): 2, (South): 3

# %%
df_north_interval_count.to_excel('extra_post_processing/PTA-1min/PTA-line2-NORTH-pointed-OB.xlsx')

# %%
df_south_interval_count.to_excel('extra_post_processing/PTA-1min/PTA-line2-SOUTH-pointed-OB.xlsx')
